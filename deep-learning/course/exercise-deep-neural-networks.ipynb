# %% [markdown]
# **This notebook is an exercise in the [Intro to Deep Learning](https://www.kaggle.com/learn/intro-to-deep-learning) course. You can reference the tutorial at [this link](https://www.kaggle.com/ryanholbrook/deep-neural-networks).**
#
# ---

# %% [markdown]
# # Introduction
#
# In the tutorial, we saw how to build deep neural networks by stacking layers inside a `Sequential` model. By adding an _activation function_ after the hidden layers, we gave the network the ability to learn more complex (non-linear) relationships in the data.
#
# In these exercises, you'll build a neural network with several hidden layers and then explore some activation functions beyond ReLU. Run this next cell to set everything up!

# %%
from learntools.deep_learning_intro.ex2 import *
from learntools.core import binder
import tensorflow as tf

# Setup plotting
import matplotlib.pyplot as plt

plt.style.use('seaborn-whitegrid')
# Set Matplotlib defaults
plt.rc('figure', autolayout=True)
plt.rc('axes', labelweight='bold', labelsize='large',
       titleweight='bold', titlesize=18, titlepad=10)

# Setup feedback system
binder.bind(globals())
# Out:
# /home/wcyat/dev/kaggle/code/venv/lib/python3.10/site-packages/learntools/deep_learning_intro/ex2.py:126: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if layer.__class__.__name__ is 'Dense']

# %% [markdown]
# In the _Concrete_ dataset, your task is to predict the compressive strength of concrete manufactured according to various recipes.
#
# Run the next code cell without changes to load the dataset.

# %%
import pandas as pd

concrete = pd.read_csv('../input/dl-course-data/concrete.csv')
concrete.head()
# Out:
#    Cement  BlastFurnaceSlag  FlyAsh  Water  Superplasticizer  CoarseAggregate  \
# 0   540.0               0.0     0.0  162.0               2.5           1040.0
# 1   540.0               0.0     0.0  162.0               2.5           1055.0
# 2   332.5             142.5     0.0  228.0               0.0            932.0
# 3   332.5             142.5     0.0  228.0               0.0            932.0
# 4   198.6             132.4     0.0  192.0               0.0            978.4
#
#    FineAggregate  Age  CompressiveStrength
# 0          676.0   28                79.99
# 1          676.0   28                61.89
# 2          594.0  270                40.27
# 3          594.0  365                41.05
# 4          825.5  360                44.30

# %% [markdown]
# # 1) Input Shape
#
# The target for this task is the column `'CompressiveStrength'`. The remaining columns are the features we'll use as inputs.
#
# What would be the input shape for this dataset?

# %%
# YOUR CODE HERE
input_shape = [8]

# Check your answer
q_1.check()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /home/wcyat/dev/kaggle/code/deep-learning/course/exercise-deep-neural-networks.ipynb Cell 7 in <cell line: 5>()
#       <a href='vscode-notebook-cell:/home/wcyat/dev/kaggle/code/deep-learning/course/exercise-deep-neural-networks.ipynb#ch0000006?line=1'>2</a> input_shape = [8]
#       <a href='vscode-notebook-cell:/home/wcyat/dev/kaggle/code/deep-learning/course/exercise-deep-neural-networks.ipynb#ch0000006?line=3'>4</a> # Check your answer
# ----> <a href='vscode-notebook-cell:/home/wcyat/dev/kaggle/code/deep-learning/course/exercise-deep-neural-networks.ipynb#ch0000006?line=4'>5</a> q_1.check()
#
# File ~/dev/kaggle/code/venv/lib/python3.10/site-packages/learntools/core/problem_view.py:24, in record.<locals>.wrapped(self, *args, **kwargs)
#      21 @functools.wraps(method)
#      22 def wrapped(self, *args, **kwargs):
#      23     self.interactions[method.__name__] += 1
# ---> 24     return method(self, *args, **kwargs)
#
# File ~/dev/kaggle/code/venv/lib/python3.10/site-packages/learntools/core/problem_view.py:15, in displayer.<locals>.wrapped(*args, **kwargs)
#      13 @functools.wraps(fn)
#      14 def wrapped(*args, **kwargs):
# ---> 15     res = fn(*args, **kwargs)
#      16     display(res)
#
# File ~/dev/kaggle/code/venv/lib/python3.10/site-packages/learntools/core/problem_view.py:87, in ProblemView.check(self)
#      85 try:
#      86     if isinstance(self.problem, CodingProblem):
# ---> 87         args = self._get_injected_args()
#      88     else:
#      89         args = ()
#
# File ~/dev/kaggle/code/venv/lib/python3.10/site-packages/learntools/core/problem_view.py:128, in ProblemView._get_injected_args(self)
#     126 def _get_injected_args(self):
#     127     names = self.problem.injectable_vars
# --> 128     missing = set(names) - self.globals.keys()
#     129     if len(missing) == 0:
#     130         return self.globals.lookup(names)
#
# File ~/dev/kaggle/code/venv/lib/python3.10/site-packages/learntools/core/globals_binder.py:41, in ReadOnlyGlobals.keys(self)
#      40 def keys(self):
# ---> 41     return self.g.keys()
#
# AttributeError: 'NoneType' object has no attribute 'keys'

# %%
# Lines below will give you a hint or solution code
# q_1.hint()
q_1.solution()
# Out:
# Solution:
# ```python
#
# input_shape = [8]
# # you could also use a 1-tuple, like input_shape = (8,)
#
# ```

# %% [markdown]
# # 2) Define a Model with Hidden Layers
#
# Now create a model with three hidden layers, each having 512 units and the ReLU activation. Be sure to include an output layer of one unit and no activation, and also `input_shape` as an argument to the first layer.

# %%
from tensorflow import keras
layers = keras.layers

# YOUR CODE HERE
model = keras.Sequential(
    [layers.Dense(512, input_shape=input_shape, activation='relu'),
     *[layers.Dense(512, activation="relu") for _ in range(0, 2)],
     layers.Dense(1)
     ]
)

# Check your answer
q_2.check()
# Out:
# Correct

# %%
# Lines below will give you a hint or solution code
# q_2.hint()
# q_2.solution()

# %% [markdown]
# # 3) Activation Layers
#
# Let's explore activations functions some.
#
# The usual way of attaching an activation function to a `Dense` layer is to include it as part of the definition with the `activation` argument. Sometimes though you'll want to put some other layer between the `Dense` layer and its activation function. (We'll see an example of this in Lesson 5 with _batch normalization_.) In this case, we can define the activation in its own `Activation` layer, like so:
#
# ```
# layers.Dense(units=8),
# layers.Activation('relu')
# ```
#
# This is completely equivalent to the ordinary way: `layers.Dense(units=8, activation='relu')`.
#
# Rewrite the following model so that each activation is in its own `Activation` layer.

# %%
# YOUR CODE HERE: rewrite this to use activation layers
model = keras.Sequential([
    layers.Dense(32, input_shape=[8]),
    layers.Activation('relu'),
    layers.Dense(32),
    layers.Activation('relu'),
    layers.Dense(1),
])

# Check your answer
q_3.check()
# Out:
# Correct

# %%
# Lines below will give you a hint or solution code
# q_3.hint()
# q_3.solution()

# %% [markdown]
# # Optional: Alternatives to ReLU
#
# There is a whole family of variants of the `'relu'` activation -- `'elu'`, `'selu'`, and `'swish'`, among others -- all of which you can use in Keras. Sometimes one activation will perform better than another on a given task, so you could consider experimenting with activations as you develop a model. The ReLU activation tends to do well on most problems, so it's a good one to start with.
#
# Let's look at the graphs of some of these. Change the activation from `'relu'` to one of the others named above. Then run the cell to see the graph. (Check out the [documentation](https://www.tensorflow.org/api_docs/python/tf/keras/activations) for more ideas.)

# %%
# YOUR CODE HERE: Change 'relu' to 'elu', 'selu', 'swish'... or something else
activation_layer = layers.Activation('swish')

x = tf.linspace(-3.0, 3.0, 100)
# once created, a layer is callable just like a function
y = activation_layer(x)

plt.figure(dpi=100)
plt.plot(x, y)
plt.xlim(-3, 3)
plt.xlabel("Input")
plt.ylabel("Output")
plt.show()

# %% [markdown]
# # Keep Going
#
# Now move on to Lesson 3 and [**learn how to train neural networks**](https://www.kaggle.com/ryanholbrook/stochastic-gradient-descent) with stochastic gradient descent.

# %% [markdown]
# ---
#
# _Have questions or comments? Visit the [course discussion forum](https://www.kaggle.com/learn/intro-to-deep-learning/discussion) to chat with other learners._
